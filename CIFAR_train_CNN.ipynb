# %%
import torch
DATA = 'CIFAR'
prefix = 'cifar_cnn_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = None
print(torch.cuda.get_device_name(0))
# Out:
# Tesla V100-SXM2-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Mounted at /content/gdrive

# %%
pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=29a18ac3b75c7216f1eceb38cad2c107a435848662d8116415b71e44e8015f92
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Collecting dcor
#   Downloading https://files.pythonhosted.org/packages/14/15/f49cbce4fc43455b387ba1512c7242db4e9181b1c1aaa6c8eb8412226c16/dcor-0.5.3-py2.py3-none-any.whl
# Collecting pytorch-msssim
#   Downloading https://files.pythonhosted.org/packages/9d/d3/3cb0f397232cf79e1762323c3a8862e39ad53eca0bb5f6be9ccc8e7c070e/pytorch_msssim-0.2.1-py3-none-any.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)
# Installing collected packages: dcor, pytorch-msssim
# Successfully installed dcor-0.5.3 pytorch-msssim-0.2.1
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 50000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            nn.Conv2d(3, 64, 3, 1, 1), #32
            nn.ReLU(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #16
            nn.Dropout(0.5),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #8
            nn.Dropout(0.5),
            
            nn.Conv2d(128, 256, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),
            
            nn.Conv2d(256, 256, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #4
            nn.Dropout(0.5),
            
            nn.Conv2d(256, 512, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #2
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #1
            nn.Dropout(0.5),
        )
        self.classifier = nn.Sequential(
            nn.Linear(1 * 512, 4096),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, 1000),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1000, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network(), 0.0001)

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 2.20348215 and Accuracy: 19.27%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 2.04265881 and Accuracy: 27.20%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 1.99435174 and Accuracy: 31.20%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 1.91426110 and Accuracy: 34.30%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 1.81646192 and Accuracy: 38.76%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 1.67326391 and Accuracy: 43.11%
# Saving the model state dictionary for Epoch: 8 with Validation loss: 1.64091980 and Accuracy: 45.59%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 1.54554045 and Accuracy: 49.76%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 1.50402415 and Accuracy: 51.93%
# Saving the model state dictionary for Epoch: 12 with Validation loss: 1.40287900 and Accuracy: 53.34%
# Saving the model state dictionary for Epoch: 13 with Validation loss: 1.31119275 and Accuracy: 56.30%
# Saving the model state dictionary for Epoch: 14 with Validation loss: 1.25423217 and Accuracy: 58.13%
# Saving the model state dictionary for Epoch: 15 with Validation loss: 1.19361329 and Accuracy: 60.29%
# Saving the model state dictionary for Epoch: 19 with Validation loss: 1.13900185 and Accuracy: 62.11%
# Saving the model state dictionary for Epoch: 20 with Validation loss: 1.09540462 and Accuracy: 63.99%
# Saving the model state dictionary for Epoch: 21 with Validation loss: 1.06818175 and Accuracy: 65.51%
# Saving the model state dictionary for Epoch: 23 with Validation loss: 1.00257683 and Accuracy: 66.94%
# Saving the model state dictionary for Epoch: 24 with Validation loss: 0.98628473 and Accuracy: 67.67%
# Saving the model state dictionary for Epoch: 27 with Validation loss: 0.89962500 and Accuracy: 70.13%
# Saving the model state dictionary for Epoch: 30 with Validation loss: 0.86704338 and Accuracy: 71.64%
# Saving the model state dictionary for Epoch: 33 with Validation loss: 0.84088093 and Accuracy: 72.26%
# Saving the model state dictionary for Epoch: 34 with Validation loss: 0.82352090 and Accuracy: 73.16%
# Saving the model state dictionary for Epoch: 35 with Validation loss: 0.78405136 and Accuracy: 74.07%
# Saving the model state dictionary for Epoch: 39 with Validation loss: 0.76421231 and Accuracy: 74.67%
# Saving the model state dictionary for Epoch: 40 with Validation loss: 0.69588053 and Accuracy: 76.99%
# Saving the model state dictionary for Epoch: 49 with Validation loss: 0.67254817 and Accuracy: 77.13%
# Saving the model state dictionary for Epoch: 54 with Validation loss: 0.67207897 and Accuracy: 77.50%
# Saving the model state dictionary for Epoch: 56 with Validation loss: 0.66754025 and Accuracy: 78.19%
# Saving the model state dictionary for Epoch: 62 with Validation loss: 0.66690832 and Accuracy: 78.41%
# Saving the model state dictionary for Epoch: 63 with Validation loss: 0.63093483 and Accuracy: 79.19%
# Saving the model state dictionary for Epoch: 64 with Validation loss: 0.62309372 and Accuracy: 79.69%
# Saving the model state dictionary for Epoch: 79 with Validation loss: 0.60155755 and Accuracy: 80.63%
# Saving the model state dictionary for Epoch: 82 with Validation loss: 0.59865379 and Accuracy: 80.29%
# Saving the model state dictionary for Epoch: 85 with Validation loss: 0.58726114 and Accuracy: 80.86%
# Saving the model state dictionary for Epoch: 100 with Validation loss: 0.58632493 and Accuracy: 81.00%
# Saving the model state dictionary for Epoch: 105 with Validation loss: 0.57936674 and Accuracy: 81.37%
# Saving the model state dictionary for Epoch: 109 with Validation loss: 0.57519126 and Accuracy: 81.21%
# Saving the model state dictionary for Epoch: 111 with Validation loss: 0.57155538 and Accuracy: 81.56%
# Saving the model state dictionary for Epoch: 113 with Validation loss: 0.56702840 and Accuracy: 81.74%
# Saving the model state dictionary for Epoch: 143 with Validation loss: 0.52208662 and Accuracy: 82.90%
# Saving the model state dictionary for Epoch: 293 with Validation loss: 0.51766253 and Accuracy: 83.19%
# Saving the model state dictionary for Epoch: 303 with Validation loss: 0.51621991 and Accuracy: 82.87%
# Saving the model state dictionary for Epoch: 309 with Validation loss: 0.51468122 and Accuracy: 83.10%
# Saving the model state dictionary for Epoch: 340 with Validation loss: 0.51445812 and Accuracy: 83.41%

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.8379, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.836

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(0.8698, device='cuda:0') 0.6744449422778629 tensor(0.0555, device='cuda:0')
