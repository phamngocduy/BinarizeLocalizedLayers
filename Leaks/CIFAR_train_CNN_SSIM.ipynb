# %%
import torch
DATA = 'CIFAR'
prefix = 'cifar_cnn_ssim_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = 'SSIM'
print(torch.cuda.get_device_name(0))
# Out:
# Tesla V100-SXM2-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Mounted at /content/gdrive

# %%
pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=ac02d0c02af97c900b3ee5ad27fa615f479c38bf8c87738ce2227c9d8c05f231
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Collecting dcor
#   Downloading https://files.pythonhosted.org/packages/14/15/f49cbce4fc43455b387ba1512c7242db4e9181b1c1aaa6c8eb8412226c16/dcor-0.5.3-py2.py3-none-any.whl
# Collecting pytorch-msssim
#   Downloading https://files.pythonhosted.org/packages/9d/d3/3cb0f397232cf79e1762323c3a8862e39ad53eca0bb5f6be9ccc8e7c070e/pytorch_msssim-0.2.1-py3-none-any.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)
# Installing collected packages: dcor, pytorch-msssim
# Successfully installed dcor-0.5.3 pytorch-msssim-0.2.1
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 50000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            nn.Conv2d(3, 64, 3, 1, 1), #32
            nn.ReLU(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #16
            nn.Dropout(0.5),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #8
            nn.Dropout(0.5),
            
            nn.Conv2d(128, 256, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),
            
            nn.Conv2d(256, 256, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #4
            nn.Dropout(0.5),
            
            nn.Conv2d(256, 512, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #2
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #1
            nn.Dropout(0.5),
        )
        self.classifier = nn.Sequential(
            nn.Linear(1 * 512, 4096),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, 1000),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1000, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network(), 0.0001)

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(0,1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 2.15043616 and Accuracy: 19.84%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 2.01598454 and Accuracy: 28.03%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 1.83939791 and Accuracy: 40.20%
# Saving the model state dictionary for Epoch: 9 with Validation loss: 1.66714799 and Accuracy: 46.39%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 1.46826398 and Accuracy: 50.41%
# Saving the model state dictionary for Epoch: 12 with Validation loss: 1.46091950 and Accuracy: 51.54%
# Saving the model state dictionary for Epoch: 13 with Validation loss: 1.42878163 and Accuracy: 52.99%
# Saving the model state dictionary for Epoch: 14 with Validation loss: 1.34186590 and Accuracy: 55.50%
# Saving the model state dictionary for Epoch: 15 with Validation loss: 1.34171391 and Accuracy: 55.36%
# Saving the model state dictionary for Epoch: 17 with Validation loss: 1.18003261 and Accuracy: 60.17%
# Saving the model state dictionary for Epoch: 18 with Validation loss: 1.17357695 and Accuracy: 60.71%
# Saving the model state dictionary for Epoch: 20 with Validation loss: 1.17107201 and Accuracy: 62.01%
# Saving the model state dictionary for Epoch: 23 with Validation loss: 1.08030260 and Accuracy: 64.26%
# Saving the model state dictionary for Epoch: 26 with Validation loss: 1.01729202 and Accuracy: 65.89%
# Saving the model state dictionary for Epoch: 28 with Validation loss: 0.90411872 and Accuracy: 69.07%
# Saving the model state dictionary for Epoch: 32 with Validation loss: 0.85922050 and Accuracy: 71.13%
# Saving the model state dictionary for Epoch: 36 with Validation loss: 0.84083861 and Accuracy: 71.81%
# Saving the model state dictionary for Epoch: 37 with Validation loss: 0.82430446 and Accuracy: 72.46%
# Saving the model state dictionary for Epoch: 38 with Validation loss: 0.79867578 and Accuracy: 73.59%
# Saving the model state dictionary for Epoch: 40 with Validation loss: 0.79532504 and Accuracy: 73.46%
# Saving the model state dictionary for Epoch: 41 with Validation loss: 0.78895462 and Accuracy: 73.66%
# Saving the model state dictionary for Epoch: 43 with Validation loss: 0.75246197 and Accuracy: 75.20%
# Saving the model state dictionary for Epoch: 45 with Validation loss: 0.72285730 and Accuracy: 75.81%
# Saving the model state dictionary for Epoch: 47 with Validation loss: 0.70909339 and Accuracy: 76.19%
# Saving the model state dictionary for Epoch: 48 with Validation loss: 0.70809126 and Accuracy: 76.80%
# Saving the model state dictionary for Epoch: 49 with Validation loss: 0.69572055 and Accuracy: 76.53%
# Saving the model state dictionary for Epoch: 53 with Validation loss: 0.63806617 and Accuracy: 78.31%
# Saving the model state dictionary for Epoch: 62 with Validation loss: 0.63426572 and Accuracy: 78.74%
# Saving the model state dictionary for Epoch: 64 with Validation loss: 0.61526269 and Accuracy: 79.30%
# Saving the model state dictionary for Epoch: 71 with Validation loss: 0.60428697 and Accuracy: 80.34%
# Saving the model state dictionary for Epoch: 73 with Validation loss: 0.60234457 and Accuracy: 80.36%
# Saving the model state dictionary for Epoch: 79 with Validation loss: 0.59831059 and Accuracy: 80.06%
# Saving the model state dictionary for Epoch: 81 with Validation loss: 0.57491070 and Accuracy: 81.21%
# Saving the model state dictionary for Epoch: 91 with Validation loss: 0.56759393 and Accuracy: 81.44%
# Saving the model state dictionary for Epoch: 96 with Validation loss: 0.55303079 and Accuracy: 82.00%
# Saving the model state dictionary for Epoch: 111 with Validation loss: 0.54647875 and Accuracy: 81.86%
# Saving the model state dictionary for Epoch: 122 with Validation loss: 0.54625773 and Accuracy: 82.41%
# Saving the model state dictionary for Epoch: 123 with Validation loss: 0.54599512 and Accuracy: 82.07%
# Saving the model state dictionary for Epoch: 130 with Validation loss: 0.52904689 and Accuracy: 82.84%
# Saving the model state dictionary for Epoch: 175 with Validation loss: 0.51672941 and Accuracy: 82.73%
# Saving the model state dictionary for Epoch: 187 with Validation loss: 0.51245987 and Accuracy: 83.54%
# Saving the model state dictionary for Epoch: 196 with Validation loss: 0.50678325 and Accuracy: 83.00%
# Saving the model state dictionary for Epoch: 249 with Validation loss: 0.49985930 and Accuracy: 83.44%
# Saving the model state dictionary for Epoch: 271 with Validation loss: 0.49334282 and Accuracy: 84.27%
# Saving the model state dictionary for Epoch: 354 with Validation loss: 0.49023050 and Accuracy: 84.11%
# Saving the model state dictionary for Epoch: 356 with Validation loss: 0.48819792 and Accuracy: 84.21%
# Saving the model state dictionary for Epoch: 391 with Validation loss: 0.48740926 and Accuracy: 84.54%
# Saving the model state dictionary for Epoch: 396 with Validation loss: 0.48603377 and Accuracy: 83.90%

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.8454, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.8353333333333334

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(0.7865, device='cuda:0') 0.6686181331265746 tensor(0.0450, device='cuda:0')
