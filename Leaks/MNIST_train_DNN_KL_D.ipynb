# %%
import torch
DATA = 'MNIST'
prefix = 'mnist_dnn_kl_d_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = 'KL_D'
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Requirement already satisfied: dcor in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=938.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 60000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            BinaryConv2d(1, 6, 3, 1, 1), #28
            nn.BatchNorm2d(6),
            BinaryRelu(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(1,1/7)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.11696529 and Accuracy: 96.16%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.08261865 and Accuracy: 97.30%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.07200560 and Accuracy: 97.64%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.05861326 and Accuracy: 98.19%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 0.05584835 and Accuracy: 98.34%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.05451341 and Accuracy: 98.17%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 0.05253841 and Accuracy: 98.46%
# Saving the model state dictionary for Epoch: 8 with Validation loss: 0.04458218 and Accuracy: 98.50%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 0.04237596 and Accuracy: 98.51%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 0.03650955 and Accuracy: 98.89%
# Saving the model state dictionary for Epoch: 18 with Validation loss: 0.03207903 and Accuracy: 99.00%
# Saving the model state dictionary for Epoch: 48 with Validation loss: 0.03127328 and Accuracy: 99.03%
# Saving the model state dictionary for Epoch: 49 with Validation loss: 0.03070415 and Accuracy: 99.07%
# Saving the model state dictionary for Epoch: 53 with Validation loss: 0.02799271 and Accuracy: 99.07%
# Updating learning rate as [0.0005, 0.001, 0.001, 0.001]
# Saving the model state dictionary for Epoch: 107 with Validation loss: 0.02777758 and Accuracy: 99.11%
# Saving the model state dictionary for Epoch: 149 with Validation loss: 0.02777022 and Accuracy: 99.13%
# Updating learning rate as [0.00025, 0.001, 0.001, 0.001]
# Updating learning rate as [0.000125, 0.001, 0.001, 0.001]
# Updating learning rate as [6.25e-05, 0.001, 0.001, 0.001]

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.9920, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.988

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(4.3642, device='cuda:0') 0.8892811071143755 tensor(0.2492, device='cuda:0')
