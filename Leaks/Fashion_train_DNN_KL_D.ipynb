# %%
import torch
DATA = 'Fashion'
prefix = 'fashion_dnn_kl_d_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = 'KL_D'
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Mounted at /content/gdrive

# %%
pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=9a1f8b5a798bf73daad31150a705af419f6936e008f0be3f1e24a3df784f15c6
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Collecting dcor
#   Downloading https://files.pythonhosted.org/packages/14/15/f49cbce4fc43455b387ba1512c7242db4e9181b1c1aaa6c8eb8412226c16/dcor-0.5.3-py2.py3-none-any.whl
# Collecting pytorch-msssim
#   Downloading https://files.pythonhosted.org/packages/9d/d3/3cb0f397232cf79e1762323c3a8862e39ad53eca0bb5f6be9ccc8e7c070e/pytorch_msssim-0.2.1-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)
# Installing collected packages: dcor, pytorch-msssim
# Successfully installed dcor-0.5.3 pytorch-msssim-0.2.1
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=938.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 60000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            BinaryConv2d(1, 6, 3, 1, 1), #28
            nn.BatchNorm2d(6),
            BinaryRelu(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(1,2)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.56807858 and Accuracy: 76.73%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.49366710 and Accuracy: 80.34%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.43138990 and Accuracy: 83.66%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.42243981 and Accuracy: 83.87%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 0.39402968 and Accuracy: 84.76%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.38889137 and Accuracy: 85.04%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 0.37511569 and Accuracy: 85.77%
# Saving the model state dictionary for Epoch: 8 with Validation loss: 0.36648953 and Accuracy: 86.26%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 0.36300722 and Accuracy: 86.06%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 0.36091745 and Accuracy: 85.99%
# Saving the model state dictionary for Epoch: 12 with Validation loss: 0.35093787 and Accuracy: 86.43%
# Saving the model state dictionary for Epoch: 14 with Validation loss: 0.34590283 and Accuracy: 86.67%
# Saving the model state dictionary for Epoch: 15 with Validation loss: 0.34307554 and Accuracy: 86.47%
# Saving the model state dictionary for Epoch: 17 with Validation loss: 0.34107882 and Accuracy: 86.89%
# Saving the model state dictionary for Epoch: 21 with Validation loss: 0.33196241 and Accuracy: 87.24%
# Saving the model state dictionary for Epoch: 33 with Validation loss: 0.33090195 and Accuracy: 87.54%
# Saving the model state dictionary for Epoch: 40 with Validation loss: 0.32524553 and Accuracy: 87.70%
# Saving the model state dictionary for Epoch: 41 with Validation loss: 0.31875125 and Accuracy: 87.86%
# Saving the model state dictionary for Epoch: 67 with Validation loss: 0.31785238 and Accuracy: 88.06%
# Saving the model state dictionary for Epoch: 77 with Validation loss: 0.31299156 and Accuracy: 87.97%
# Saving the model state dictionary for Epoch: 94 with Validation loss: 0.31296089 and Accuracy: 87.99%
# Updating learning rate as [0.0005, 0.001, 0.001, 0.001]
# Saving the model state dictionary for Epoch: 140 with Validation loss: 0.31075922 and Accuracy: 88.34%
# Updating learning rate as [0.00025, 0.001, 0.001, 0.001]
# Saving the model state dictionary for Epoch: 283 with Validation loss: 0.30896881 and Accuracy: 88.17%
# Saving the model state dictionary for Epoch: 284 with Validation loss: 0.30857635 and Accuracy: 88.49%
# Saving the model state dictionary for Epoch: 287 with Validation loss: 0.30649048 and Accuracy: 88.31%
# Updating learning rate as [0.000125, 0.001, 0.001, 0.001]
# Saving the model state dictionary for Epoch: 331 with Validation loss: 0.30618840 and Accuracy: 88.70%
# Updating learning rate as [6.25e-05, 0.001, 0.001, 0.001]

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.8877, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.8906666666666667

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(5.7994, device='cuda:0') 0.9057849099541536 tensor(0.1319, device='cuda:0')
