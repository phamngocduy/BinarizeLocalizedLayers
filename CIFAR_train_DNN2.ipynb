# %%
import torch
DATA = 'CIFAR'
prefix = 'cifar_dnn2_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = None
print(torch.cuda.get_device_name(0))
# Out:
# Tesla V100-SXM2-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Mounted at /content/gdrive

# %%
pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=71cd3023bc5fee68b4b390f6f7e9c5d8195f5ce88846517b1298abeacb032779
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Collecting dcor
#   Downloading https://files.pythonhosted.org/packages/14/15/f49cbce4fc43455b387ba1512c7242db4e9181b1c1aaa6c8eb8412226c16/dcor-0.5.3-py2.py3-none-any.whl
# Collecting pytorch-msssim
#   Downloading https://files.pythonhosted.org/packages/9d/d3/3cb0f397232cf79e1762323c3a8862e39ad53eca0bb5f6be9ccc8e7c070e/pytorch_msssim-0.2.1-py3-none-any.whl
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)
# Installing collected packages: dcor, pytorch-msssim
# Successfully installed dcor-0.5.3 pytorch-msssim-0.2.1
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 50000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            BinaryConv2d(3, 64, 3, 1, 1), #32
            nn.BatchNorm2d(64),
            BinaryTanh(),
            nn.MaxPool2d(2), #16
            #nn.Dropout(0.1),

            BinaryConv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            BinaryRelu(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #8
            nn.Dropout(0.1),            
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(128, 256, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            nn.Conv2d(256, 256, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #4
            nn.Dropout(0.5),
            
            nn.Conv2d(256, 512, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #2
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #1
            nn.Dropout(0.5),
        )
        self.classifier = nn.Sequential(
            nn.Linear(1 * 512, 4096),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, 1000),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1000, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network(), 0.0001)

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 1.89214075 and Accuracy: 30.54%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 1.57261479 and Accuracy: 41.27%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 1.45763695 and Accuracy: 47.10%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 1.29275262 and Accuracy: 53.00%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 1.26658499 and Accuracy: 54.47%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 1.22219694 and Accuracy: 56.84%
# Saving the model state dictionary for Epoch: 13 with Validation loss: 1.17216516 and Accuracy: 59.17%
# Saving the model state dictionary for Epoch: 15 with Validation loss: 1.08294129 and Accuracy: 62.57%
# Saving the model state dictionary for Epoch: 16 with Validation loss: 1.03025222 and Accuracy: 63.94%
# Saving the model state dictionary for Epoch: 22 with Validation loss: 0.98693639 and Accuracy: 66.03%
# Saving the model state dictionary for Epoch: 23 with Validation loss: 0.96448624 and Accuracy: 66.27%
# Saving the model state dictionary for Epoch: 28 with Validation loss: 0.94540787 and Accuracy: 67.01%
# Saving the model state dictionary for Epoch: 29 with Validation loss: 0.90799457 and Accuracy: 68.81%
# Saving the model state dictionary for Epoch: 30 with Validation loss: 0.90603691 and Accuracy: 68.81%
# Saving the model state dictionary for Epoch: 38 with Validation loss: 0.87808818 and Accuracy: 70.04%
# Saving the model state dictionary for Epoch: 44 with Validation loss: 0.83182406 and Accuracy: 70.99%
# Saving the model state dictionary for Epoch: 49 with Validation loss: 0.80167836 and Accuracy: 72.41%
# Saving the model state dictionary for Epoch: 55 with Validation loss: 0.76891148 and Accuracy: 73.71%
# Saving the model state dictionary for Epoch: 64 with Validation loss: 0.75026655 and Accuracy: 74.56%
# Saving the model state dictionary for Epoch: 70 with Validation loss: 0.73095208 and Accuracy: 75.41%
# Saving the model state dictionary for Epoch: 86 with Validation loss: 0.72817588 and Accuracy: 75.83%
# Saving the model state dictionary for Epoch: 97 with Validation loss: 0.72570181 and Accuracy: 75.69%
# Saving the model state dictionary for Epoch: 98 with Validation loss: 0.72385418 and Accuracy: 75.63%
# Updating learning rate as [5e-05, 0.0001, 0.0001, 0.0001]
# Saving the model state dictionary for Epoch: 104 with Validation loss: 0.71536243 and Accuracy: 76.34%
# Saving the model state dictionary for Epoch: 112 with Validation loss: 0.70603102 and Accuracy: 76.29%
# Saving the model state dictionary for Epoch: 115 with Validation loss: 0.69828039 and Accuracy: 76.63%
# Saving the model state dictionary for Epoch: 129 with Validation loss: 0.68767601 and Accuracy: 77.09%
# Saving the model state dictionary for Epoch: 146 with Validation loss: 0.68248296 and Accuracy: 76.96%
# Saving the model state dictionary for Epoch: 157 with Validation loss: 0.68164384 and Accuracy: 77.27%
# Saving the model state dictionary for Epoch: 158 with Validation loss: 0.68117678 and Accuracy: 76.76%
# Saving the model state dictionary for Epoch: 178 with Validation loss: 0.67729741 and Accuracy: 77.01%
# Saving the model state dictionary for Epoch: 196 with Validation loss: 0.67638391 and Accuracy: 77.34%
# Updating learning rate as [2.5e-05, 0.0001, 0.0001, 0.0001]
# Saving the model state dictionary for Epoch: 222 with Validation loss: 0.66149575 and Accuracy: 77.63%
# Saving the model state dictionary for Epoch: 238 with Validation loss: 0.65398186 and Accuracy: 78.26%
# Saving the model state dictionary for Epoch: 284 with Validation loss: 0.64637184 and Accuracy: 78.11%
# Saving the model state dictionary for Epoch: 285 with Validation loss: 0.64598048 and Accuracy: 78.20%
# Saving the model state dictionary for Epoch: 300 with Validation loss: 0.64465582 and Accuracy: 78.39%
# Updating learning rate as [1.25e-05, 0.0001, 0.0001, 0.0001]
# Saving the model state dictionary for Epoch: 324 with Validation loss: 0.63191962 and Accuracy: 78.26%
# Saving the model state dictionary for Epoch: 341 with Validation loss: 0.63091969 and Accuracy: 79.01%
# Saving the model state dictionary for Epoch: 343 with Validation loss: 0.62759990 and Accuracy: 78.83%
# Saving the model state dictionary for Epoch: 397 with Validation loss: 0.62556851 and Accuracy: 79.04%
# Updating learning rate as [6.25e-06, 0.0001, 0.0001, 0.0001]

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.7954, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.7866666666666666

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(1.3225, device='cuda:0') 0.783808515168302 tensor(0.1201, device='cuda:0')
