# %%
import torch
DATA = 'MNIST'
prefix = 'mnist_dnn_'
traing = True
epochs = 200
batch_size = 64
leaks_loss = None
print(torch.cuda.get_device_name(0))
# Out:
# Tesla V100-SXM2-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Mounted at /content/gdrive

# %%
pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=f4591ef4f69951d22f238f2519385daedc0c6f1bf45848920e571feb6b99cabe
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Collecting dcor
#   Downloading https://files.pythonhosted.org/packages/14/15/f49cbce4fc43455b387ba1512c7242db4e9181b1c1aaa6c8eb8412226c16/dcor-0.5.3-py2.py3-none-any.whl
# Collecting pytorch-msssim
#   Downloading https://files.pythonhosted.org/packages/9d/d3/3cb0f397232cf79e1762323c3a8862e39ad53eca0bb5f6be9ccc8e7c070e/pytorch_msssim-0.2.1-py3-none-any.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)
# Installing collected packages: dcor, pytorch-msssim
# Successfully installed dcor-0.5.3 pytorch-msssim-0.2.1
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=938.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 60000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            BinaryConv2d(1, 6, 5, 1, 2), #28
            nn.BatchNorm2d(6),
            BinaryRelu(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.09854683 and Accuracy: 96.90%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.07122162 and Accuracy: 97.76%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.05933003 and Accuracy: 98.17%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.05422451 and Accuracy: 98.36%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 0.05011235 and Accuracy: 98.39%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.04771891 and Accuracy: 98.47%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 0.04650966 and Accuracy: 98.50%
# Saving the model state dictionary for Epoch: 9 with Validation loss: 0.04102053 and Accuracy: 98.93%
# Saving the model state dictionary for Epoch: 13 with Validation loss: 0.03702432 and Accuracy: 98.94%
# Saving the model state dictionary for Epoch: 14 with Validation loss: 0.03658795 and Accuracy: 98.90%
# Saving the model state dictionary for Epoch: 16 with Validation loss: 0.03613533 and Accuracy: 98.89%
# Saving the model state dictionary for Epoch: 17 with Validation loss: 0.03556295 and Accuracy: 98.81%
# Saving the model state dictionary for Epoch: 20 with Validation loss: 0.03509942 and Accuracy: 98.97%
# Saving the model state dictionary for Epoch: 22 with Validation loss: 0.03491046 and Accuracy: 98.93%
# Saving the model state dictionary for Epoch: 24 with Validation loss: 0.03422733 and Accuracy: 99.07%
# Saving the model state dictionary for Epoch: 26 with Validation loss: 0.03225376 and Accuracy: 98.99%
# Saving the model state dictionary for Epoch: 31 with Validation loss: 0.02994713 and Accuracy: 99.09%
# Saving the model state dictionary for Epoch: 34 with Validation loss: 0.02888684 and Accuracy: 99.03%
# Saving the model state dictionary for Epoch: 37 with Validation loss: 0.02841204 and Accuracy: 99.13%
# Saving the model state dictionary for Epoch: 74 with Validation loss: 0.02768774 and Accuracy: 99.06%
# Saving the model state dictionary for Epoch: 95 with Validation loss: 0.02701966 and Accuracy: 99.19%
# Updating learning rate as [0.0005, 0.001, 0.001, 0.001]
# Saving the model state dictionary for Epoch: 127 with Validation loss: 0.02585139 and Accuracy: 99.23%
# Saving the model state dictionary for Epoch: 146 with Validation loss: 0.02576032 and Accuracy: 99.10%
# Updating learning rate as [0.00025, 0.001, 0.001, 0.001]

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.9923, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.9926666666666667

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(3.4225, device='cuda:0') 0.7601452659758868 tensor(0.1799, device='cuda:0')
