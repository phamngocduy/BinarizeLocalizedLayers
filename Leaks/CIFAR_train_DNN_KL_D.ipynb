# %%
import torch
DATA = 'CIFAR'
prefix = 'cifar_dnn_kl_d_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = 'KL_D'
print(torch.cuda.get_device_name(0))
# Out:
# Tesla V100-SXM2-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Requirement already satisfied: dcor in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 50000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            BinaryConv2d(3, 64, 3, 1, 1), #32
            nn.BatchNorm2d(64),
            BinaryRelu(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #16
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #8
            nn.Dropout(0.2),
            
            nn.Conv2d(128, 256, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),
            
            nn.Conv2d(256, 256, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #4
            nn.Dropout(0.5),
            
            nn.Conv2d(256, 512, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #2
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Conv2d(512, 512, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2), #1
            nn.Dropout(0.5),
        )
        self.classifier = nn.Sequential(
            nn.Linear(1 * 512, 4096),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(4096, 1000),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1000, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network(), 0.0001)

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(1,1/5)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 1.85069561 and Accuracy: 26.87%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 1.71295285 and Accuracy: 36.06%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 1.52288151 and Accuracy: 43.27%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 1.47284985 and Accuracy: 45.79%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 1.38618863 and Accuracy: 50.03%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 1.32905483 and Accuracy: 53.40%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 1.15462387 and Accuracy: 59.83%
# Saving the model state dictionary for Epoch: 16 with Validation loss: 1.03616655 and Accuracy: 64.56%
# Saving the model state dictionary for Epoch: 22 with Validation loss: 1.02742922 and Accuracy: 65.34%
# Saving the model state dictionary for Epoch: 24 with Validation loss: 0.97092938 and Accuracy: 66.99%
# Saving the model state dictionary for Epoch: 28 with Validation loss: 0.90077543 and Accuracy: 69.83%
# Saving the model state dictionary for Epoch: 29 with Validation loss: 0.86528766 and Accuracy: 70.41%
# Saving the model state dictionary for Epoch: 43 with Validation loss: 0.83724350 and Accuracy: 72.57%
# Saving the model state dictionary for Epoch: 49 with Validation loss: 0.83685577 and Accuracy: 72.84%
# Saving the model state dictionary for Epoch: 50 with Validation loss: 0.77434522 and Accuracy: 73.76%
# Saving the model state dictionary for Epoch: 51 with Validation loss: 0.70918483 and Accuracy: 76.14%
# Saving the model state dictionary for Epoch: 72 with Validation loss: 0.68714529 and Accuracy: 76.47%
# Saving the model state dictionary for Epoch: 80 with Validation loss: 0.66474122 and Accuracy: 77.64%
# Saving the model state dictionary for Epoch: 82 with Validation loss: 0.65634793 and Accuracy: 78.17%
# Saving the model state dictionary for Epoch: 84 with Validation loss: 0.65138078 and Accuracy: 78.19%
# Saving the model state dictionary for Epoch: 90 with Validation loss: 0.64863735 and Accuracy: 78.43%
# Updating learning rate as [5e-05, 0.0001, 0.0001, 0.0001]
# Saving the model state dictionary for Epoch: 103 with Validation loss: 0.62996030 and Accuracy: 78.83%
# Saving the model state dictionary for Epoch: 122 with Validation loss: 0.62523603 and Accuracy: 79.37%
# Saving the model state dictionary for Epoch: 145 with Validation loss: 0.59960908 and Accuracy: 80.46%
# Saving the model state dictionary for Epoch: 162 with Validation loss: 0.59862429 and Accuracy: 80.07%
# Saving the model state dictionary for Epoch: 177 with Validation loss: 0.58200616 and Accuracy: 80.81%
# Saving the model state dictionary for Epoch: 182 with Validation loss: 0.57640111 and Accuracy: 80.97%
# Updating learning rate as [2.5e-05, 0.0001, 0.0001, 0.0001]
# Saving the model state dictionary for Epoch: 210 with Validation loss: 0.57552105 and Accuracy: 80.86%
# Saving the model state dictionary for Epoch: 232 with Validation loss: 0.56850404 and Accuracy: 80.94%
# Saving the model state dictionary for Epoch: 257 with Validation loss: 0.55817634 and Accuracy: 81.34%
# Updating learning rate as [1.25e-05, 0.0001, 0.0001, 0.0001]
# Saving the model state dictionary for Epoch: 312 with Validation loss: 0.54980826 and Accuracy: 81.93%
# Saving the model state dictionary for Epoch: 335 with Validation loss: 0.54738235 and Accuracy: 81.77%
# Saving the model state dictionary for Epoch: 344 with Validation loss: 0.53981912 and Accuracy: 81.83%
# Saving the model state dictionary for Epoch: 400 with Validation loss: 0.53709167 and Accuracy: 81.94%
# Updating learning rate as [6.25e-06, 0.0001, 0.0001, 0.0001]

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.8217, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.837

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(3.0529, device='cuda:0') 0.7960292412408965 tensor(0.0973, device='cuda:0')
