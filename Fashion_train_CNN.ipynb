# %%
import torch
DATA = 'Fashion'
prefix = 'fashion_cnn_'
traing = True
epochs = 200
batch_size = 64
leaks_loss = None
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Requirement already satisfied: dcor in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=938.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 60000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            nn.Conv2d(1, 6, 5, 1, 2), #28
            nn.ReLU(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.51098353 and Accuracy: 80.79%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.43329090 and Accuracy: 84.27%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.38530779 and Accuracy: 85.46%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.36212134 and Accuracy: 86.59%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 0.34597054 and Accuracy: 86.71%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.33470002 and Accuracy: 87.40%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 0.32109350 and Accuracy: 88.21%
# Saving the model state dictionary for Epoch: 8 with Validation loss: 0.31107691 and Accuracy: 88.89%
# Saving the model state dictionary for Epoch: 9 with Validation loss: 0.30631021 and Accuracy: 88.90%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 0.30463177 and Accuracy: 88.69%
# Saving the model state dictionary for Epoch: 12 with Validation loss: 0.29036734 and Accuracy: 89.21%
# Saving the model state dictionary for Epoch: 13 with Validation loss: 0.28637031 and Accuracy: 89.54%
# Saving the model state dictionary for Epoch: 17 with Validation loss: 0.28131366 and Accuracy: 90.13%
# Saving the model state dictionary for Epoch: 18 with Validation loss: 0.27598137 and Accuracy: 89.84%
# Saving the model state dictionary for Epoch: 20 with Validation loss: 0.27276462 and Accuracy: 90.16%
# Saving the model state dictionary for Epoch: 22 with Validation loss: 0.26609948 and Accuracy: 90.39%
# Saving the model state dictionary for Epoch: 23 with Validation loss: 0.26400015 and Accuracy: 90.29%
# Saving the model state dictionary for Epoch: 25 with Validation loss: 0.26331577 and Accuracy: 90.41%
# Saving the model state dictionary for Epoch: 30 with Validation loss: 0.25490880 and Accuracy: 90.89%
# Saving the model state dictionary for Epoch: 36 with Validation loss: 0.25398475 and Accuracy: 90.97%
# Saving the model state dictionary for Epoch: 40 with Validation loss: 0.25387576 and Accuracy: 91.20%
# Saving the model state dictionary for Epoch: 45 with Validation loss: 0.25134715 and Accuracy: 91.13%
# Saving the model state dictionary for Epoch: 51 with Validation loss: 0.24730609 and Accuracy: 91.09%
# Saving the model state dictionary for Epoch: 85 with Validation loss: 0.24620999 and Accuracy: 91.33%

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.9166, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.9133333333333333

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(1.8528, device='cuda:0') 0.8024402582853711 tensor(0.1330, device='cuda:0')
