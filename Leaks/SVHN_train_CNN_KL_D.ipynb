# %%
import torch
DATA = 'SVHN'
prefix = 'svhn_cnn_kl_d_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = 'KL_D'
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Mounted at /content/gdrive

# %%
pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=382933b7b9ee403d6b0bfde212eb7543fd858a41957cd3b6eeec13c345783acb
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Collecting dcor
#   Downloading https://files.pythonhosted.org/packages/14/15/f49cbce4fc43455b387ba1512c7242db4e9181b1c1aaa6c8eb8412226c16/dcor-0.5.3-py2.py3-none-any.whl
# Collecting pytorch-msssim
#   Downloading https://files.pythonhosted.org/packages/9d/d3/3cb0f397232cf79e1762323c3a8862e39ad53eca0bb5f6be9ccc8e7c070e/pytorch_msssim-0.2.1-py3-none-any.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)
# Installing collected packages: dcor, pytorch-msssim
# Successfully installed dcor-0.5.3 pytorch-msssim-0.2.1
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# Using downloaded and verified file: /content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/data/train_32x32.mat
# Using downloaded and verified file: /content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/data/test_32x32.mat
# HBox(children=(FloatProgress(value=0.0, max=1145.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 73257 18222 7810 26032

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            nn.Conv2d(3, 6, 5, 1, 1), #28
            nn.ReLU(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(0,1/3)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.74525481 and Accuracy: 78.67%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.58958089 and Accuracy: 82.60%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.53859669 and Accuracy: 84.10%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.49947184 and Accuracy: 85.28%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 0.46481475 and Accuracy: 86.15%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.45492733 and Accuracy: 86.42%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 0.44206119 and Accuracy: 86.76%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 0.42695028 and Accuracy: 87.27%
# Saving the model state dictionary for Epoch: 13 with Validation loss: 0.41374943 and Accuracy: 87.55%
# Saving the model state dictionary for Epoch: 15 with Validation loss: 0.39201126 and Accuracy: 88.48%
# Saving the model state dictionary for Epoch: 19 with Validation loss: 0.39139491 and Accuracy: 88.34%
# Saving the model state dictionary for Epoch: 21 with Validation loss: 0.39019707 and Accuracy: 88.46%
# Saving the model state dictionary for Epoch: 22 with Validation loss: 0.38602170 and Accuracy: 88.66%
# Saving the model state dictionary for Epoch: 30 with Validation loss: 0.38174656 and Accuracy: 88.82%
# Saving the model state dictionary for Epoch: 32 with Validation loss: 0.37738574 and Accuracy: 89.04%
# Saving the model state dictionary for Epoch: 35 with Validation loss: 0.36875841 and Accuracy: 89.37%
# Saving the model state dictionary for Epoch: 41 with Validation loss: 0.36723387 and Accuracy: 89.27%
# Saving the model state dictionary for Epoch: 44 with Validation loss: 0.36694899 and Accuracy: 89.31%
# Saving the model state dictionary for Epoch: 47 with Validation loss: 0.36632022 and Accuracy: 89.34%
# Saving the model state dictionary for Epoch: 55 with Validation loss: 0.36571446 and Accuracy: 89.53%
# Saving the model state dictionary for Epoch: 56 with Validation loss: 0.36550009 and Accuracy: 89.40%
# Saving the model state dictionary for Epoch: 58 with Validation loss: 0.35904381 and Accuracy: 89.56%
# Saving the model state dictionary for Epoch: 68 with Validation loss: 0.35494748 and Accuracy: 89.73%
# Saving the model state dictionary for Epoch: 77 with Validation loss: 0.35130504 and Accuracy: 90.04%
# Saving the model state dictionary for Epoch: 86 with Validation loss: 0.35094935 and Accuracy: 90.06%
# Saving the model state dictionary for Epoch: 87 with Validation loss: 0.34537521 and Accuracy: 90.18%
# Saving the model state dictionary for Epoch: 111 with Validation loss: 0.34433123 and Accuracy: 90.37%
# Saving the model state dictionary for Epoch: 116 with Validation loss: 0.34307230 and Accuracy: 90.30%
# Saving the model state dictionary for Epoch: 146 with Validation loss: 0.34291181 and Accuracy: 90.15%
# Saving the model state dictionary for Epoch: 148 with Validation loss: 0.34143728 and Accuracy: 90.37%
# Saving the model state dictionary for Epoch: 159 with Validation loss: 0.34140414 and Accuracy: 90.40%
# Saving the model state dictionary for Epoch: 177 with Validation loss: 0.34105909 and Accuracy: 90.41%
# Saving the model state dictionary for Epoch: 179 with Validation loss: 0.33758551 and Accuracy: 90.48%
# Saving the model state dictionary for Epoch: 190 with Validation loss: 0.33502769 and Accuracy: 90.76%
# Saving the model state dictionary for Epoch: 223 with Validation loss: 0.33471951 and Accuracy: 90.62%
# Saving the model state dictionary for Epoch: 342 with Validation loss: 0.33444941 and Accuracy: 90.67%

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.9097, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7810.0), HTML(value='')))
# Test accuracy: 0.9030729833546735

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7810.0), HTML(value='')))
# tensor(1.5940, device='cuda:0') 0.7204883252208706 tensor(0.0432, device='cuda:0')
