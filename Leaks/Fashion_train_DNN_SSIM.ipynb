# %%
import torch
DATA = 'Fashion'
prefix = 'fashion_dnn_ssim_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = 'SSIM'
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Requirement already satisfied: dcor in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=938.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 60000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            BinaryConv2d(1, 6, 3, 1, 2), #28
            nn.BatchNorm2d(6),
            BinaryRelu(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(1,1/5)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.55312675 and Accuracy: 78.26%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.48076990 and Accuracy: 81.90%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.43696854 and Accuracy: 83.69%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.40009540 and Accuracy: 84.81%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 0.38844469 and Accuracy: 85.04%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.37791067 and Accuracy: 85.40%
# Saving the model state dictionary for Epoch: 8 with Validation loss: 0.36059508 and Accuracy: 86.29%
# Saving the model state dictionary for Epoch: 9 with Validation loss: 0.36009732 and Accuracy: 86.51%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 0.35549864 and Accuracy: 86.49%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 0.34997678 and Accuracy: 86.70%
# Saving the model state dictionary for Epoch: 13 with Validation loss: 0.33845672 and Accuracy: 87.09%
# Saving the model state dictionary for Epoch: 19 with Validation loss: 0.33246145 and Accuracy: 87.40%
# Saving the model state dictionary for Epoch: 34 with Validation loss: 0.32774043 and Accuracy: 87.40%
# Saving the model state dictionary for Epoch: 39 with Validation loss: 0.32328784 and Accuracy: 87.86%
# Saving the model state dictionary for Epoch: 77 with Validation loss: 0.32195893 and Accuracy: 87.79%
# Saving the model state dictionary for Epoch: 80 with Validation loss: 0.32058701 and Accuracy: 87.93%
# Saving the model state dictionary for Epoch: 92 with Validation loss: 0.31630349 and Accuracy: 88.26%
# Updating learning rate as [0.0005, 0.001, 0.001, 0.001]
# Saving the model state dictionary for Epoch: 105 with Validation loss: 0.31455681 and Accuracy: 88.27%
# Saving the model state dictionary for Epoch: 109 with Validation loss: 0.31392771 and Accuracy: 88.23%
# Saving the model state dictionary for Epoch: 157 with Validation loss: 0.31021541 and Accuracy: 88.07%
# Saving the model state dictionary for Epoch: 194 with Validation loss: 0.30768552 and Accuracy: 88.46%
# Updating learning rate as [0.00025, 0.001, 0.001, 0.001]
# Updating learning rate as [0.000125, 0.001, 0.001, 0.001]
# Updating learning rate as [6.25e-05, 0.001, 0.001, 0.001]

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.8856, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.889

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(3.2478, device='cuda:0') 0.7359125776194819 tensor(0.0848, device='cuda:0')
