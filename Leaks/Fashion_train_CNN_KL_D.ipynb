# %%
import torch
DATA = 'Fashion'
prefix = 'fashion_cnn_kl_d_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = 'KL_D'
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Requirement already satisfied: dcor in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=938.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 60000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            nn.Conv2d(1, 6, 3, 1, 1), #28
            nn.ReLU(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(0,6)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.49899986 and Accuracy: 79.69%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.41038945 and Accuracy: 84.40%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.37621254 and Accuracy: 85.76%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.34859273 and Accuracy: 86.96%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 0.33127850 and Accuracy: 87.56%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.32358417 and Accuracy: 87.47%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 0.31413731 and Accuracy: 88.13%
# Saving the model state dictionary for Epoch: 8 with Validation loss: 0.30828074 and Accuracy: 88.14%
# Saving the model state dictionary for Epoch: 9 with Validation loss: 0.30750063 and Accuracy: 88.27%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 0.30248544 and Accuracy: 88.71%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 0.30232888 and Accuracy: 88.47%
# Saving the model state dictionary for Epoch: 12 with Validation loss: 0.29713225 and Accuracy: 88.84%
# Saving the model state dictionary for Epoch: 13 with Validation loss: 0.29407388 and Accuracy: 88.81%
# Saving the model state dictionary for Epoch: 14 with Validation loss: 0.28141126 and Accuracy: 88.84%
# Saving the model state dictionary for Epoch: 17 with Validation loss: 0.27828634 and Accuracy: 89.44%
# Saving the model state dictionary for Epoch: 19 with Validation loss: 0.27658361 and Accuracy: 89.87%
# Saving the model state dictionary for Epoch: 20 with Validation loss: 0.27193356 and Accuracy: 89.87%
# Saving the model state dictionary for Epoch: 21 with Validation loss: 0.26930389 and Accuracy: 89.81%
# Saving the model state dictionary for Epoch: 22 with Validation loss: 0.26692030 and Accuracy: 89.74%
# Saving the model state dictionary for Epoch: 24 with Validation loss: 0.25677443 and Accuracy: 90.54%
# Saving the model state dictionary for Epoch: 31 with Validation loss: 0.25175247 and Accuracy: 90.57%
# Saving the model state dictionary for Epoch: 37 with Validation loss: 0.25077471 and Accuracy: 90.26%
# Saving the model state dictionary for Epoch: 39 with Validation loss: 0.24941923 and Accuracy: 90.50%
# Saving the model state dictionary for Epoch: 44 with Validation loss: 0.24630852 and Accuracy: 91.03%
# Saving the model state dictionary for Epoch: 53 with Validation loss: 0.24541134 and Accuracy: 90.89%
# Saving the model state dictionary for Epoch: 64 with Validation loss: 0.24364392 and Accuracy: 91.21%
# Saving the model state dictionary for Epoch: 67 with Validation loss: 0.24292587 and Accuracy: 90.74%
# Saving the model state dictionary for Epoch: 72 with Validation loss: 0.24291033 and Accuracy: 90.96%
# Saving the model state dictionary for Epoch: 78 with Validation loss: 0.24238716 and Accuracy: 91.20%
# Saving the model state dictionary for Epoch: 79 with Validation loss: 0.24172124 and Accuracy: 90.96%
# Saving the model state dictionary for Epoch: 82 with Validation loss: 0.24155976 and Accuracy: 91.26%
# Saving the model state dictionary for Epoch: 85 with Validation loss: 0.24110079 and Accuracy: 90.96%
# Saving the model state dictionary for Epoch: 87 with Validation loss: 0.24051408 and Accuracy: 91.09%
# Saving the model state dictionary for Epoch: 91 with Validation loss: 0.24029441 and Accuracy: 90.94%
# Saving the model state dictionary for Epoch: 95 with Validation loss: 0.23962301 and Accuracy: 91.00%
# Saving the model state dictionary for Epoch: 103 with Validation loss: 0.23941746 and Accuracy: 90.99%
# Saving the model state dictionary for Epoch: 104 with Validation loss: 0.23854598 and Accuracy: 91.39%
# Saving the model state dictionary for Epoch: 107 with Validation loss: 0.23752214 and Accuracy: 91.33%
# Saving the model state dictionary for Epoch: 125 with Validation loss: 0.23631418 and Accuracy: 91.24%
# Saving the model state dictionary for Epoch: 157 with Validation loss: 0.23270473 and Accuracy: 91.56%
# Saving the model state dictionary for Epoch: 215 with Validation loss: 0.22934571 and Accuracy: 91.50%

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.9184, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.911

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(2.2443, device='cuda:0') 0.6835870780584047 tensor(0.0977, device='cuda:0')
