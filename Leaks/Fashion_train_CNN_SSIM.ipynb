# %%
import torch
DATA = 'Fashion'
prefix = 'fashion_cnn_ssim_'
traing = True
epochs = 400
batch_size = 64
leaks_loss = 'SSIM'
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Requirement already satisfied: dcor in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=938.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 60000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            nn.Conv2d(1, 6, 3, 1, 2), #28
            nn.ReLU(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(0,3)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=400.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.52553201 and Accuracy: 79.36%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.43586329 and Accuracy: 83.73%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.40141654 and Accuracy: 84.90%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.36434010 and Accuracy: 86.36%
# Saving the model state dictionary for Epoch: 5 with Validation loss: 0.35297164 and Accuracy: 86.74%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.33391488 and Accuracy: 87.53%
# Saving the model state dictionary for Epoch: 8 with Validation loss: 0.31318402 and Accuracy: 88.60%
# Saving the model state dictionary for Epoch: 9 with Validation loss: 0.30878255 and Accuracy: 88.76%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 0.29885888 and Accuracy: 88.99%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 0.29491320 and Accuracy: 89.23%
# Saving the model state dictionary for Epoch: 14 with Validation loss: 0.29100204 and Accuracy: 89.30%
# Saving the model state dictionary for Epoch: 16 with Validation loss: 0.28316209 and Accuracy: 89.57%
# Saving the model state dictionary for Epoch: 18 with Validation loss: 0.27818665 and Accuracy: 89.61%
# Saving the model state dictionary for Epoch: 20 with Validation loss: 0.27334481 and Accuracy: 89.97%
# Saving the model state dictionary for Epoch: 23 with Validation loss: 0.27238262 and Accuracy: 90.07%
# Saving the model state dictionary for Epoch: 30 with Validation loss: 0.26590109 and Accuracy: 90.31%
# Saving the model state dictionary for Epoch: 33 with Validation loss: 0.26357970 and Accuracy: 90.53%
# Saving the model state dictionary for Epoch: 34 with Validation loss: 0.26339069 and Accuracy: 90.26%
# Saving the model state dictionary for Epoch: 39 with Validation loss: 0.26337427 and Accuracy: 90.39%
# Saving the model state dictionary for Epoch: 41 with Validation loss: 0.26032883 and Accuracy: 90.39%
# Saving the model state dictionary for Epoch: 47 with Validation loss: 0.25608715 and Accuracy: 90.59%
# Saving the model state dictionary for Epoch: 103 with Validation loss: 0.25592762 and Accuracy: 90.73%
# Saving the model state dictionary for Epoch: 109 with Validation loss: 0.25328639 and Accuracy: 90.73%
# Saving the model state dictionary for Epoch: 312 with Validation loss: 0.25280669 and Accuracy: 91.10%
# Saving the model state dictionary for Epoch: 397 with Validation loss: 0.25249299 and Accuracy: 90.90%

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.9110, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.909

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(2.2517, device='cuda:0') 0.705871376890434 tensor(0.0830, device='cuda:0')
