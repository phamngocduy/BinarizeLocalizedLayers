# %%
import torch
DATA = 'Fashion'
prefix = 'fashion_dnn_'
traing = True
epochs = 200
batch_size = 64
leaks_loss = None
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
import os
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/MyDrive/Colab Notebooks/BinarizeLocalize/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)

# %%
import import_ipynb
os.chdir(root_path + 'library')
Call_Template = True
# %run Template.ipynb
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.7/dist-packages (0.1.3)
# Requirement already satisfied: dcor in /usr/local/lib/python3.7/dist-packages (0.5.3)
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.19.5)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.7/dist-packages (from dcor) (0.51.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dcor) (1.4.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pytorch-msssim) (1.8.1+cu101)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.51->dcor) (56.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pytorch-msssim) (3.7.4.3)

# %% [markdown]
# ##Fetching the dataset and preparing train, validation and test data loaders

# %%
(trainSet, validSet, checkSet, testSet,
 trainSetGPU, validSetGPU, checkSetGPU) = load_data_to_gpu()
print(len(trainSet), len(validSet), len(checkSet), len(testSet))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=938.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 60000 7000 3000 10000

# %% [markdown]
# ##Visualising the data

# %%
plot_samples(trainSet, None)

# %%
class Network(Model):
    def __init__(self):
        super(Network, self).__init__()
        # at client
        self.feature0 = nn.Sequential(
            BinaryConv2d(1, 6, 5, 1, 2), #28
            nn.BatchNorm2d(6),
            BinaryRelu(),
        )
        self.feature1 = nn.Sequential(
            nn.MaxPool2d(2), #14
            #nn.Dropout(0.1),
        )
        # at server
        self.feature2 = nn.Sequential(
            nn.Conv2d(6, 16, 5, 1, 0), #10
            nn.ReLU(),
            nn.MaxPool2d(2), #5
            nn.Dropout(0.2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(25 * 16, 120),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(84, 10)
        )

# %% [markdown]
# ##Defining model object, loss function and optimiser

# %%
(model, criterion, dataleaks, optimizer) = init_training(Network())

# %% [markdown]
# ##Training and Validation

# %%
(trainLoss, validLoss, leaksLoss, accuracyList) = train_model(1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# Saving the model state dictionary for Epoch: 1 with Validation loss: 0.50115281 and Accuracy: 80.87%
# Saving the model state dictionary for Epoch: 2 with Validation loss: 0.42521471 and Accuracy: 83.80%
# Saving the model state dictionary for Epoch: 3 with Validation loss: 0.40894818 and Accuracy: 84.94%
# Saving the model state dictionary for Epoch: 4 with Validation loss: 0.37785572 and Accuracy: 86.00%
# Saving the model state dictionary for Epoch: 6 with Validation loss: 0.36608616 and Accuracy: 86.21%
# Saving the model state dictionary for Epoch: 7 with Validation loss: 0.34877867 and Accuracy: 86.73%
# Saving the model state dictionary for Epoch: 10 with Validation loss: 0.34758860 and Accuracy: 87.01%
# Saving the model state dictionary for Epoch: 11 with Validation loss: 0.34758696 and Accuracy: 87.41%
# Saving the model state dictionary for Epoch: 12 with Validation loss: 0.33740589 and Accuracy: 87.13%
# Saving the model state dictionary for Epoch: 15 with Validation loss: 0.33538514 and Accuracy: 87.29%
# Saving the model state dictionary for Epoch: 17 with Validation loss: 0.33425200 and Accuracy: 87.47%
# Saving the model state dictionary for Epoch: 22 with Validation loss: 0.32830942 and Accuracy: 87.79%
# Saving the model state dictionary for Epoch: 28 with Validation loss: 0.32548058 and Accuracy: 87.87%
# Saving the model state dictionary for Epoch: 32 with Validation loss: 0.31612611 and Accuracy: 88.20%
# Saving the model state dictionary for Epoch: 46 with Validation loss: 0.31361023 and Accuracy: 88.34%
# Saving the model state dictionary for Epoch: 51 with Validation loss: 0.30853251 and Accuracy: 88.80%
# Saving the model state dictionary for Epoch: 52 with Validation loss: 0.30644557 and Accuracy: 88.81%
# Saving the model state dictionary for Epoch: 93 with Validation loss: 0.30483595 and Accuracy: 88.86%
# Saving the model state dictionary for Epoch: 98 with Validation loss: 0.30315080 and Accuracy: 89.11%
# Updating learning rate as [0.0005, 0.001, 0.001, 0.001]
# Saving the model state dictionary for Epoch: 102 with Validation loss: 0.29834986 and Accuracy: 89.14%
# Saving the model state dictionary for Epoch: 163 with Validation loss: 0.29730749 and Accuracy: 89.54%
# Saving the model state dictionary for Epoch: 171 with Validation loss: 0.29581341 and Accuracy: 89.24%
# Updating learning rate as [0.00025, 0.001, 0.001, 0.001]

# %%
(model, trainLoss, validLoss, leaksLoss, accuracyList) = save_and_load()

# %%
plot_losses()
# Out:
# Max accuracy is tensor(0.8954, device='cuda:0')

# %%
test_model()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# Test accuracy: 0.8966666666666666

# %% [markdown]
# ##Measuring Privacy Preserving

# %%
plot_measure(measure_image(testSet[1][0]))

# %%
plot_measures(measure_images())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3000.0), HTML(value='')))
# tensor(4.7856, device='cuda:0') 0.8804492949515516 tensor(0.1084, device='cuda:0')
